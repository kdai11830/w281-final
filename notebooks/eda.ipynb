# %% [markdown]
# # Notebook for general EDA

# %% [markdown]
# ## Data Loading

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import cv2
import os
import random
from tqdm import tqdm
from skimage.feature import hog

# %%
220*0.6
# Out:
# 132.0

# %%
from utils import *

# %%
get_random_pics_by_class('data')

# %%
data = load_dataset('data', limit_to=25)
# Out:
# Airport
#   7%|▋         | 26/360 [00:00<00:02, 129.92it/s]
# BareLand
#   8%|▊         | 26/310 [00:00<00:01, 223.96it/s]
# BaseballField
#  12%|█▏        | 26/220 [00:00<00:01, 147.75it/s]
# Beach
#   6%|▋         | 26/400 [00:00<00:01, 237.37it/s]
# Bridge
#   7%|▋         | 26/360 [00:00<00:01, 227.16it/s]
# Center
#  10%|█         | 26/260 [00:00<00:01, 175.09it/s]
# Church
#  11%|█         | 26/240 [00:00<00:00, 258.01it/s]
# Commercial
#   7%|▋         | 26/350 [00:00<00:01, 234.05it/s]
# DenseResidential
#   6%|▋         | 26/410 [00:00<00:02, 145.01it/s]
# Desert
#   9%|▊         | 26/300 [00:00<00:00, 308.82it/s]
# Farmland
#   7%|▋         | 26/370 [00:00<00:01, 277.10it/s]
# Forest
#  10%|█         | 26/250 [00:00<00:00, 246.67it/s]
# Industrial
#   7%|▋         | 26/390 [00:00<00:01, 236.91it/s]
# Meadow
#   9%|▉         | 26/280 [00:00<00:01, 212.42it/s]
# MediumResidential
#   9%|▉         | 26/290 [00:00<00:01, 165.85it/s]
# Mountain
# ...

# %%
plot_distribution_of_images_per_class(data=data)

# %%
# rgb features
rgb_features = get_rgb_features(data=data)

# %%
plot_hist_per_class(data, rgb_features)

# %%
visualize_rgb_features(data)
